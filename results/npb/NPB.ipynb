# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline

# BT
bt_kvm = [174.58, 172.69, 170.27]    # Syscatch HC - KVM
bt_uhyve = [173.30, 173.24, 174.65]  # Syscatch HC - uhyve
bt_linux = [174.60, 174.85, 174.68]  # Native Linux
bt_kvm_native = [178.24, 180.75, 185.98]                   # Native HC - KVM
bt_uhyve_native = [176.66, 180.96, 175.76]                 # Native HC - uhyve
bt_kvm_mean = np.mean(bt_kvm)
bt_kvm_std = np.std(bt_kvm)
bt_uhyve_mean = np.mean(bt_uhyve)
bt_uhyve_std = np.std(bt_uhyve)
bt_linux_mean = np.mean(bt_linux)
bt_linux_std = np.std(bt_linux)
bt_kvm_native_mean = np.mean(bt_kvm_native)
bt_kvm_native_std = np.std(bt_kvm_native)
bt_uhyve_native_mean = np.mean(bt_uhyve_native)
bt_uhyve_native_std = np.std(bt_uhyve_native)

bt_plot = [bt_kvm_mean, bt_kvm_native_mean, bt_uhyve_mean, bt_uhyve_native_mean, bt_linux_mean]
bt_err = [bt_kvm_std, bt_kvm_native_std, bt_uhyve_std, bt_uhyve_native_std, bt_linux_std]

# CG
cg_kvm = [50.13, 48.58, 47.66]
cg_uhyve = [51.86, 52.49, 52.07]
cg_linux = [48.28, 48.61, 50.18]
cg_kvm_native = [49.80, 50.60, 51.16]
cg_uhyve_native = [52.32, 49.57, 49.83]
cg_kvm_mean = np.mean(cg_kvm)
cg_kvm_std = np.std(cg_kvm)
cg_uhyve_mean = np.mean(cg_uhyve)
cg_uhyve_std = np.std(cg_uhyve)
cg_linux_mean = np.mean(cg_linux)
cg_linux_std = np.std(cg_linux)
cg_kvm_native_mean = np.mean(cg_kvm_native)
cg_kvm_native_std = np.std(cg_kvm_native)
cg_uhyve_native_mean = np.mean(cg_uhyve_native)
cg_uhyve_native_std = np.std(cg_uhyve_native)

cg_plot = [cg_kvm_mean, cg_kvm_native_mean, cg_uhyve_mean, cg_uhyve_native_mean, cg_linux_mean]
cg_err = [cg_kvm_std, cg_kvm_native_std, cg_uhyve_std, cg_uhyve_native_std, cg_linux_std]

# IS
is_kvm = [0.92, 1.48, 1.33]
is_uhyve = [1.43, 1.39, 1.42]
is_linux = [1.40, 1.36, 1.38]
is_kvm_native = [1.40, 1.38, 1.38]
is_uhyve_native = [1.41, 1.41, 1.34]
is_kvm_mean = np.mean(is_kvm)
is_kvm_std = np.std(is_kvm)
is_uhyve_mean = np.mean(is_uhyve)
is_uhyve_std = np.std(is_uhyve)
is_linux_mean = np.mean(is_linux)
is_linux_std = np.std(is_linux)
is_kvm_native_mean = np.mean(is_kvm_native)
is_kvm_native_std = np.std(is_kvm_native)
is_uhyve_native_mean = np.mean(is_uhyve_native)
is_uhyve_native_std = np.std(is_uhyve_native)

is_plot = [is_kvm_mean, is_kvm_native_mean, is_uhyve_mean, is_uhyve_native_mean, is_linux_mean]
is_err = [is_kvm_std, is_kvm_native_std, is_uhyve_std, is_uhyve_native_std, is_linux_std]

# EP
ep_kvm = [90.10, 88.08, 87.65]
ep_uhyve = [86.50, 87.96, 87.04]
ep_linux = [85.56, 86.33, 85.58]
ep_kvm_native = [88.49, 91.68, 92.07]
ep_uhyve_native = [89.83, 91.93, 90.26]
ep_kvm_mean = np.mean(ep_kvm)
ep_kvm_std = np.std(ep_kvm)
ep_uhyve_mean = np.mean(ep_uhyve)
ep_uhyve_std = np.std(ep_uhyve)
ep_linux_mean = np.mean(ep_linux)
ep_linux_std = np.std(ep_linux)
ep_kvm_native_mean = np.mean(ep_kvm_native)
ep_kvm_native_std = np.std(ep_kvm_native)
ep_uhyve_native_mean = np.mean(ep_uhyve_native)
ep_uhyve_native_std = np.std(ep_uhyve_native)

ep_plot = [ep_kvm_mean, ep_kvm_native_mean, ep_uhyve_mean, ep_uhyve_native_mean, ep_linux_mean]
ep_err = [ep_kvm_std, ep_kvm_native_std, ep_uhyve_std, ep_uhyve_native_std, ep_linux_std]

# MG
mg_kvm = [3.42, 3.44, 3.42]
mg_uhyve = [3.64, 3.64, 3.57]
mg_linux = [3.61, 3.56, 3.57]
mg_kvm_native = [3.59, 3.57, 3.65]
mg_uhyve_native = [3.84, 3.77, 3.76]
mg_kvm_mean = np.mean(mg_kvm)
mg_kvm_std = np.std(mg_kvm)
mg_uhyve_mean = np.mean(mg_uhyve)
mg_uhyve_std = np.std(mg_uhyve)
mg_linux_mean = np.mean(mg_linux)
mg_linux_std = np.std(mg_linux)
mg_kvm_native_mean = np.mean(mg_kvm_native)
mg_kvm_native_std = np.std(mg_kvm_native)
mg_uhyve_native_mean = np.mean(mg_uhyve_native)
mg_uhyve_native_std = np.std(mg_uhyve_native)

mg_plot = [mg_kvm_mean, mg_kvm_native_mean, mg_uhyve_mean, mg_uhyve_native_mean, mg_linux_mean]
mg_err = [mg_kvm_std, mg_kvm_native_std, mg_uhyve_std, mg_uhyve_native_std, mg_linux_std]

# SP
sp_kvm = [86.66, 87.85, 87.84]
sp_uhyve = [90.44, 90.59, 90.21]
sp_linux = [86.36, 86.66, 86.76]
sp_kvm_native = [82.24, 82.17, 82.36]
sp_uhyve_native = [83.86, 83.63, 85.27]
sp_kvm_mean = np.mean(sp_kvm)
sp_kvm_std = np.std(sp_kvm)
sp_uhyve_mean = np.mean(sp_uhyve)
sp_uhyve_std = np.std(sp_uhyve)
sp_linux_mean = np.mean(sp_linux)
sp_linux_std = np.std(sp_linux)
sp_kvm_native_mean = np.mean(sp_kvm_native)
sp_kvm_native_std = np.std(sp_kvm_native)
sp_uhyve_native_mean = np.mean(sp_uhyve_native)
sp_uhyve_native_std = np.std(sp_uhyve_native)

sp_plot = [sp_kvm_mean, sp_kvm_native_mean, sp_uhyve_mean, sp_uhyve_native_mean, sp_linux_mean]
sp_err = [sp_kvm_std, sp_kvm_native_std, sp_uhyve_std, sp_uhyve_native_std, sp_linux_std]

# UA
ua_kvm = [61.04, 62.51, 58.35]
ua_uhyve = [60.54, 58.74, 58.83]
ua_linux = [59.59, 59.02, 60.82]
ua_kvm_native = [65.77, 64.90, 64.22]
ua_uhyve_native = [63.77, 67.26, 67.12]
ua_kvm_mean = np.mean(ua_kvm)
ua_kvm_std = np.std(ua_kvm)
ua_uhyve_mean = np.mean(ua_uhyve)
ua_uhyve_std = np.std(ua_uhyve)
ua_linux_mean = np.mean(ua_linux)
ua_linux_std = np.std(ua_linux)
ua_kvm_native_mean = np.mean(ua_kvm_native)
ua_kvm_native_std = np.std(ua_kvm_native)
ua_uhyve_native_mean = np.mean(ua_uhyve_native)
ua_uhyve_native_std = np.std(ua_uhyve_native)

ua_plot = [ua_kvm_mean, ua_kvm_native_mean, ua_uhyve_mean, ua_uhyve_native_mean, ua_linux_mean]
ua_err = [ua_kvm_std, ua_kvm_native_std, ua_uhyve_std, ua_uhyve_native_std, ua_linux_std]



# Plot stuff
N = 5
fig, ax = plt.subplots()
index = np.arange(N)
bt = plt.bar(index, bt_plot, color=["skyblue", "moccasin", \
    "lightcoral", "darkseagreen", "lightpink"], yerr=bt_err)
cg = plt.bar(index + N + 1, cg_plot, color=["skyblue", "moccasin", \
    "lightcoral", "darkseagreen", "lightpink"], yerr=cg_err)
is_ = plt.bar(index + N*2 + 2, is_plot, color=["skyblue", "moccasin", \
    "lightcoral", "darkseagreen", "lightpink"], yerr=is_err)
ep = plt.bar(index + N*3 + 3, ep_plot, color=["skyblue", "moccasin", \
    "lightcoral", "darkseagreen", "lightpink"], yerr=ep_err)
mg = plt.bar(index + N*4 + 4, ep_plot, color=["skyblue", "moccasin", \
    "lightcoral", "darkseagreen", "lightpink"], yerr=mg_err)
sp = plt.bar(index + N*5 + 5, ep_plot, color=["skyblue", "moccasin", \
    "lightcoral", "darkseagreen", "lightpink"], yerr=sp_err)
ua = plt.bar(index + N*6 + 6, ua_plot, color=["skyblue", "moccasin", \
    "lightcoral", "darkseagreen", "lightpink"], yerr=ua_err)

plt.xticks((2, 8, 14, 20, 26, 32, 38, 44), ('BT', 'CG', 'IS', 'EP', 'MG',\
            'SP', 'UA'))
plt.grid()
ax.set_axisbelow(True)
l1 = mpatches.Patch(color='skyblue', label='Hermit + KVM (syscatch)')
l2 = mpatches.Patch(color='moccasin', label='Hermit + KVM')
l3 = mpatches.Patch(color='lightcoral', label='Hermit + uhyve (syscatch)')
l4 = mpatches.Patch(color='darkseagreen', label='Hermit + uhyve')
l5 = mpatches.Patch(color='lightpink', label='Native Linux')

plt.legend(handles=[l1, l2, l3, l4, l5])

plt.title("Syscall catching NPB performance - avg of 3 runs")
ax.set_ylabel('Execution time (s)')
ax.set_xlabel('Benchmark (class = B)')

plt.savefig("npb.pdf")
