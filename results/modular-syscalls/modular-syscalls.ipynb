# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# First graph: kernel vs application code size
# Minimal application doing nothing
ktext = 0x0430af
kdata = 0x58b568
kbss = 0xe3bb60
text = 0x002e1e
data = 0x000118
bss = 0x000348
rodata = 0x009330

fig, ax = plt.subplots(figsize=(3,3))
ax.set_axisbelow(True)

ax.pie([ktext, text], labels=[".ktext\n(0x0430af)", ".text\n(0x002e1e)"],
      autopct='%1.1f%%', shadow=True)

#ax.grid()
#ax.bar([1], ktext, label="kernel code size")
#ax.bar([1], text, bottom=ktext, label="application code size")

plt.savefig("ktext-vs-text.pdf", bbox_inches='tight')
plt.show()

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

ktext_base = 0x0430af
all_disabled = ktext_base - 0x04161f
print all_disabled

fig, ax = plt.subplots(figsize=(3,3))
ax.set_axisbelow(True)

ax.pie([ktext_base-0x04161f, 0x04161f], labels=[".ktext\n(0x0430af)", ".text\n(0x002e1e)"],
      autopct='%1.1f%%', shadow=True)
# Out:
# 6800
# ([<matplotlib.patches.Wedge at 0x7fe0ac5ceb50>,
#   <matplotlib.patches.Wedge at 0x7fe0ac12c3d0>],
#  [Text(1.09667,0.0854873,u'.ktext\n(0x0430af)'),
#   Text(-1.09667,-0.0854872,u'.text\n(0x002e1e)')],
#  [Text(0.598185,0.0466294,u'2.5%'), Text(-0.598185,-0.0466294,u'97.5%')])
