# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline 

matplotlib.rcParams.update({'font.size': 13})

# Class A

bta_hermitux_avg = 44.835
bta_hermitux_std = 0.342060748340928
bta_linux_avg = 44.711
bta_linux_std = 0.157370758260725
bta_docker_avg = 44.627
bta_docker_std = 0.28016066818881
bta_osv_avg = 49.651
bta_osv_std = 1.50630858576706
bta_rump_avg = 44.37
bta_rump_std = 0.182330591082364

cga_hermitux_avg = 0.831
cga_hermitux_std = 0.099716264136465
cga_linux_avg = 0.769
cga_linux_std = 0.016633299933166
cga_docker_avg = 0.799
cga_docker_std = 0.033813212407775
cga_osv_avg = 0.885
cga_osv_std = 0.056813535163531
cga_rump_avg = 0.781
cga_rump_std = 0.003162277660168

epa_hermitux_avg = 21.211
epa_hermitux_std = 0.101811372427424
epa_linux_avg = 21.105
epa_linux_std = 0.027182510717167
epa_docker_avg = 21.299
epa_docker_std = 0.113377442396821
epa_osv_avg = 21.712
epa_osv_std = 0.299881458061163
epa_rump_avg = 22.692
epa_rump_std = 0.037058512292499

isa_hermitux_avg = 0.38
isa_hermitux_std = 0.021081851067789
isa_linux_avg = 0.353
isa_linux_std = 0.017029386365926
isa_docker_avg = 0.348
isa_docker_std = 0.006324555320337
isa_osv_avg = 0.387
isa_osv_std = 0.03198958163736
isa_rump_avg = 0.35
isa_rump_std = 0

mga_hermitux_avg = 0.867
mga_hermitux_std = 0.006749485577106
mga_linux_avg = 0.832
mga_linux_std = 0.004216370213558
mga_docker_avg = 0.834
mga_docker_std = 0.005163977794943
mga_osv_avg = 0.912
mga_osv_std = 0.042373996218855
mga_rump_avg = 0.846
mga_rump_std = 0.005163977794943

spa_hermitux_avg = 24.765
spa_hermitux_std = 0.077064186811313
spa_linux_avg = 24.08
spa_linux_std = 0.140158640277525
spa_docker_avg = 24.118
spa_docker_std = 0.096009258812772
spa_osv_avg = 26.488
spa_osv_std = 0.906664215682961
spa_rump_avg = 24.12
spa_rump_std = 0.136137185711081

uaa_hermitux_avg = 13.481
uaa_hermitux_std = 0.061904945054674
uaa_linux_avg = 13.349
uaa_linux_std = 0.073401483484857
uaa_docker_avg = 13.314
uaa_docker_std = 0.069952364744398
uaa_osv_avg = 14.023
uaa_osv_std = 0.228670068001914
uaa_rump_avg = 14.582
uaa_rump_std = 0.047562823951299

bssl_hermitux_avg = 0.5707065
bssl_hermitux_std = 0.014417340849362
bssl_linux_avg = 0.5674334
bssl_linux_std = 0.020144767830217
bssl_docker_avg = 0.5674334
bssl_docker_std = 0.020144767830217
bssl_osv_avg = 0.606865
bssl_osv_std = 0.008304812339842
bssl_rump_avg = 1.3808092
bssl_rump_std = 0.014555913733676

fm_hermitux_avg = 1.3929946
fm_linux_avg = 1.3321224
fm_docker_avg = 1.3294792
fm_osv_avg = 1.7409303
fm_rump_avg = 1.9720446

sw_hermitux_avg = 0.8567368
sw_linux_avg = 0.8492034
sw_docker_avg = 0.8594558
sw_osv_avg = 0.7483059
sw_rump_avg = 1.285116

sc_hermitux_avg = 0.7545
sc_linux_avg = 0.7671
sc_docker_avg = 0.7447
sc_osv_avg = 0.7944
sc_rump_avg = 0.7283

linux_means_a = [bta_linux_avg, cga_linux_avg, epa_linux_avg, isa_linux_avg, mga_linux_avg, spa_linux_avg, uaa_linux_avg, \
              bssl_linux_avg, fm_linux_avg, sw_linux_avg, sc_linux_avg]
linux_stdevs_a = [bta_linux_std, cga_linux_std, epa_linux_std, isa_linux_std, mga_linux_std, spa_linux_std, \
                uaa_linux_std, bssl_linux_std]
hermitux_means_a = [bta_hermitux_avg, cga_hermitux_avg, epa_hermitux_avg, isa_hermitux_avg, mga_hermitux_avg, \
                  spa_hermitux_avg, uaa_hermitux_avg, bssl_hermitux_avg, fm_hermitux_avg, sw_hermitux_avg, \
                    sc_hermitux_avg]
hermitux_stdevs_a = [bta_hermitux_std, cga_hermitux_std, epa_hermitux_std, isa_hermitux_std, mga_hermitux_std, \
                  spa_hermitux_std, uaa_hermitux_std, bssl_hermitux_std]
docker_means_a = [bta_docker_avg, cga_docker_avg, epa_docker_avg, isa_docker_avg, mga_docker_avg, spa_docker_avg, \
                uaa_docker_avg, bssl_docker_avg, fm_docker_avg, sw_docker_avg, sc_docker_avg]
docker_stdevs_a = [bta_docker_std, cga_docker_std, epa_docker_std, isa_docker_std, mga_docker_std, spa_docker_std, \
                 uaa_docker_std, bssl_docker_std]
osv_means_a = [bta_osv_avg, cga_osv_avg, epa_osv_avg, isa_osv_avg, mga_osv_avg, spa_osv_avg, uaa_osv_avg, bssl_osv_avg, \
              fm_osv_avg, sw_osv_avg, sc_osv_avg]
osv_stdevs_a = [bta_osv_std, cga_osv_std, epa_osv_std, isa_osv_std, mga_osv_std, spa_osv_std, uaa_osv_std, bssl_osv_std]

rump_means_a = [bta_rump_avg, cga_rump_avg, epa_rump_avg, isa_rump_avg, mga_rump_avg, spa_rump_avg, uaa_rump_avg, \
              bssl_rump_avg, fm_rump_avg, sw_rump_avg, sc_rump_avg]
rump_stdevs_a = [bta_rump_std, cga_rump_std, epa_rump_std, isa_rump_std, mga_rump_std, spa_rump_std, uaa_rump_std, \
               bssl_rump_std]

###########################################################################################################

# fig, ax = plt.subplots()
f, (ax1, ax2) = plt.subplots(2, 1)


##########################################################################################################

#ax1.grid()
#ax1.set_axisbelow(True)

#plt.sca(ax1)
#plt.xticks((2, 8, 14, 20, 26, 32, 38, 44), ("BT class A", "CG class A", "EP class A", "IS class A",\
#                                            "MG class A", "SP class A", "UA class A", \
#                                            "Blackscholes"))

#rects1 = ax1.bar([0, 6, 12, 18, 24, 30, 36, 42], linux_means_a, yerr=linux_stdevs_a, hatch="//", color=["skyblue"], \
#                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black'])
#rects2 = ax1.bar([1, 7, 13, 19, 25, 31, 37, 43], hermitux_means_a, yerr=hermitux_stdevs_a, hatch="\\\\", color=["moccasin"], \
#                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black'])
#rects3 = ax1.bar([2, 8, 14, 20, 26, 32, 38, 44], docker_means_a, yerr=docker_stdevs_a, hatch="-", color=["lightgray"], \
#                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black'])
#rects4 = ax1.bar([3, 9, 15, 21, 27, 33, 39, 45], osv_means_a, yerr=osv_stdevs_a, color=["lightcoral"], \
#                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black'])
#rects5 = ax1.bar([4, 10, 16, 22, 28, 34, 40, 46], rump_means_a, yerr=rump_stdevs_a, hatch="+", color=["palegreen"], \
#                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black'])

#fig = matplotlib.pyplot.gcf()
#fig.subplots_adjust(bottom=0.2)
#fig.subplots_adjust(left=0.2)
#fig.set_size_inches(25,15)

#ax1.set_title("NPB class A and PARSEC Blackscholes SimLarge execution times comparison")
#ax1.set_ylabel("Execution\ntime (s)")

####################################################################################################################

#ax2.set_title("NPB class A and PARSEC Blackscholes SimLarge execution times normalized to Linux")

# normalize hermitux_a
hermitux_means_a_norm = []
for i, val in enumerate(hermitux_means_a):
    hermitux_means_a_norm.append(val/linux_means_a[i])
# normalize docker_a
docker_means_a_norm = []
for i, val in enumerate(docker_means_a):
    docker_means_a_norm.append(val/linux_means_a[i])
# normalize osv_a
osv_means_a_norm = []
for i, val in enumerate(osv_means_a):
    osv_means_a_norm.append(val/linux_means_a[i])
# normalize rump_a
rump_means_a_norm = []
for i, val in enumerate(rump_means_a):
    rump_means_a_norm.append(val/rump_means_a[i])
    
ax1.grid()
ax1.set_axisbelow(True)
    
plt.sca(ax1)
plt.xticks((2.5, 8.5, 14.5, 20.5, 26.5, 32.5, 38.5, 44.5, 51, 57, 63), ("BT", "CG", "EP", "IS", "MG", "SP", "UA", \
                                            "Blackscholes", "Freqmine", "Swaptions", "Streamcluster"),\
                                               rotation=12.5)
ax1.set_ylim(0.75, 1.5)
rects6 = ax1.bar([1, 7, 13, 19, 25, 31, 37, 43, 49, 55, 61], hermitux_means_a_norm, hatch="\\\\\\\\", color=["moccasin"], \
                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', \
                          'black'])
rects7 = ax1.bar([2, 8, 14, 20, 26, 32, 38, 44, 50, 56, 62], docker_means_a_norm, hatch="--", color=["lightgray"], \
                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', \
                           'black'])
rects8 = ax1.bar([3, 9, 15, 21, 27, 33, 39, 45, 51, 57, 63], osv_means_a_norm, color=["lightcoral"], \
                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', \
                           'black'])
rects9 = ax1.bar([4, 10, 16, 22, 28, 34, 40, 46, 52, 58, 64], rump_means_a_norm, hatch="////", color=["palegreen"], \
                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', \
                           'black'])

#ax1.set_ylabel("Exec. time\nnormalized to Linux")    
    
########################################################################################################################

#ax3.set_title("NPB class B and PARSEC Blackscholes Native execution times comparison")

btb_hermitux_mean = 186.16
btb_hermitux_std = 0.768866409433763
btb_linux_mean = 186.021
btb_linux_std = 0.566832328725956
btb_docker_mean = 187.377
btb_docker_std = 2.04729116422435
btb_osv_mean = 251.657
btb_osv_std = 51.4982010581168
btb_rump_mean = 189.311
btb_rump_std = 0.986356370126384

cgb_hermitux_mean = 92.079
cgb_hermitux_std = 0.501629566734482
cgb_linux_mean = 91.366
cgb_linux_std = 0.452528697678082
cgb_docker_mean = 90.891
cgb_docker_std = 0.257701377567137
cgb_osv_mean = 137.677
cgb_osv_std = 13.1412455438761
cgb_rump_mean = 91.005
cgb_rump_std = 0.441544008125023

epb_hermitux_mean = 84.607
epb_hermitux_std = 0.261790841024749
epb_linux_mean = 84.997
epb_linux_std = 0.355997815224254
epb_docker_mean = 84.76
epb_docker_std = 0.191485421551266
epb_osv_mean = 89.325
epb_osv_std = 2.48725305865281
epb_rump_mean = 90.787
epb_rump_std = 0.299445784371357

isb_hermitux_mean = 1.503
isb_hermitux_std = 0.034334951418182
isb_linux_mean = 1.363
isb_linux_std = 0.041109609582189
isb_docker_mean = 1.351
isb_docker_std = 0.003162277660168
isb_osv_mean = 1.544
isb_osv_std = 0.14377451481786
isb_rump_mean = 1.392
isb_rump_std = 0.004216370213558

mgb_hermitux_mean = 4.164
mgb_hermitux_std = 0.227947362344906
mgb_linux_mean = 3.985
mgb_linux_std = 0.221622802677583
mgb_docker_mean = 3.874
mgb_docker_std = 0.015055453054182
mgb_osv_mean = 4.342
mgb_osv_std = 0.231122862949077
mgb_rump_mean = 3.91
mgb_rump_std = 0.023570226039552

spb_hermitux_mean = 111.075
spb_hermitux_std = 0.649311601279043
spb_linux_mean = 109.128
spb_linux_std = 0.360209815400844
spb_docker_mean = 109.024
spb_docker_std = 0.389592379574116
spb_osv_mean = 126.317
spb_osv_std = 6.82330328930041
spb_rump_mean = 108.765
spb_rump_std = 0.411427055773224

uab_hermitux_mean = 67.804
uab_hermitux_std = 0.41992591939267
uab_linux_mean = 66.6
uab_linux_std = 0.541971708978737
uab_docker_mean = 66.736
uab_docker_std = 0.618388586929323
uab_osv_mean = 72.157
uab_osv_std = 2.27898149765782
uab_rump_mean = 77.478
uab_rump_std = 0.712909531427377

bsn_hermitux_mean = 82.612964
bsn_hermitux_std = 0.391725299006843
bsn_linux_mean = 83.0143965
bsn_linux_std = 1.68339381561807
bsn_docker_mean = 82.8901059
bsn_docker_std = 1.72583486128968
bsn_osv_mean = 94.356
bsn_osv_std = 3.61488957876539
bsn_rump_mean = 207.0946847
bsn_rump_std = 0.537632073138836

fml_hermitux_avg = 3.7108
fml_linux_avg = 3.349
fml_docker_avg = 3.338
fml_osv_avg = 3.5168
fml_rump_avg = 7.5044252

swb_hermitux_avg = 3.4127963
swb_linux_avg = 3.3984421
swb_docker_avg = 3.3950316
swb_osv_avg = 3.0370323
swb_rump_avg = 5.0933127

scb_hermitux_avg = 3.7108
scb_linux_avg = 3.349
scb_docker_avg = 3.338
scb_osv_avg = 3.5168
scb_rump_avg = 3.37

linux_means_b = [btb_linux_mean, cgb_linux_mean, epb_linux_mean, isb_linux_mean, mgb_linux_mean, spb_linux_mean,\
                uab_linux_mean, bsn_linux_mean, fml_linux_avg, swb_linux_avg, scb_linux_avg]
hermitux_means_b = [btb_hermitux_mean, cgb_hermitux_mean, epb_hermitux_mean, isb_hermitux_mean, mgb_hermitux_mean,\
                    spb_hermitux_mean, uab_hermitux_mean, bsn_hermitux_mean, fml_hermitux_avg, swb_hermitux_avg, \
                   scb_hermitux_avg]
docker_means_b = [btb_docker_mean, cgb_docker_mean, epb_docker_mean, isb_docker_mean, mgb_docker_mean, spb_docker_mean,\
                uab_docker_mean, bsn_docker_mean, fml_docker_avg, swb_docker_avg, scb_docker_avg]
osv_means_b = [btb_osv_mean, cgb_osv_mean, epb_osv_mean, isb_osv_mean, mgb_osv_mean, spb_osv_mean, uab_osv_mean, \
               bsn_osv_mean, fml_osv_avg, swb_osv_avg, scb_osv_avg]
rump_means_b = [btb_rump_mean, cgb_rump_mean, epb_rump_mean, isb_rump_mean, mgb_rump_mean, spb_rump_mean, \
                uab_rump_mean, bsn_rump_mean, fml_rump_avg, swb_rump_avg, scb_rump_avg]

linux_stdevs_b = [btb_linux_std, cgb_linux_std, epb_linux_std, isb_linux_std, mgb_linux_std, spb_linux_std,\
                uab_linux_std, bsn_linux_std]
hermitux_stdevs_b = [btb_hermitux_std, cgb_hermitux_std, epb_hermitux_std, isb_hermitux_std, mgb_hermitux_std,\
                    spb_hermitux_std, uab_hermitux_std, bsn_hermitux_std]
docker_stdevs_b = [btb_docker_std, cgb_docker_std, epb_docker_std, isb_docker_std, mgb_docker_std, spb_docker_std,\
                uab_docker_std, bsn_docker_std]
osv_stdevs_b = [btb_osv_std, cgb_osv_std, epb_osv_std, isb_osv_std, mgb_osv_std, spb_osv_std, uab_osv_std, \
               bsn_osv_std]
rump_stdevs_b = [btb_rump_std, cgb_rump_std, epb_rump_std, isb_rump_std, mgb_rump_std, spb_rump_std, \
                uab_rump_std, bsn_rump_std]

#ax3.grid()
#ax3.set_axisbelow(True)
#ax3.set_ylabel("Execution\ntime (s)")

#plt.sca(ax3)
#plt.xticks((2.5, 8.5, 14.5, 20.5, 26.5, 32.5, 38.5, 44.5), ("BT class B", "CG class B", "EP class B", "IS class B",\
#                                            "MG class B", "SP class B", "UA class B", \
#                                            "Blackscholes"))
#plt.yticks([100, 200, 300])

#rects10 = ax3.bar([0, 6, 12, 18, 24, 30, 36, 42], linux_means_b, yerr=linux_stdevs_b, hatch="//", color=["skyblue"], \
#                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black'])
#rects11 = ax3.bar([1, 7, 13, 19, 25, 31, 37, 43], hermitux_means_b, yerr=hermitux_stdevs_b, hatch="\\\\", color=["moccasin"], \
#                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black'])
#rects12 = ax3.bar([2, 8, 14, 20, 26, 32, 38, 44], docker_means_b, yerr=docker_stdevs_b, hatch="-", color=["lightgray"], \
#                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black'])
#rects13 = ax3.bar([3, 9, 15, 21, 27, 33, 39, 45], osv_means_b, yerr=osv_stdevs_b, color=["lightcoral"], \
#                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black'])
#rects14 = ax3.bar([4, 10, 16, 22, 28, 34, 40, 46], rump_means_b, yerr=rump_stdevs_b, hatch="+", color=["palegreen"], \
#                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black'])

#################################################################################################################

#ax4.set_title("NPB class B and PARSEC Blackscholes Native execution times normalized to Linux")

# normalize hermitux_
hermitux_means_b_norm = []
for i, val in enumerate(hermitux_means_b):
    hermitux_means_b_norm.append(val/linux_means_b[i])
# normalize docker_b
docker_means_b_norm = []
for i, val in enumerate(docker_means_b):
    docker_means_b_norm.append(val/linux_means_b[i])
# normalize osv_a
osv_means_b_norm = []
for i, val in enumerate(osv_means_b):
    osv_means_b_norm.append(val/linux_means_b[i])
# normalize rump_b
rump_means_b_norm = []
for i, val in enumerate(rump_means_b):
    rump_means_b_norm.append(val/linux_means_b[i])
    
ax2.grid()
ax2.set_axisbelow(True)
    
plt.sca(ax2)
plt.xticks((2.5, 8.5, 14.5, 20.5, 26.5, 32.5, 38.5, 44.5, 51, 57, 63), ("BT", "CG", "EP", "IS", "MG", "SP", "UA", \
                                            "Blackscholes", "Freqmine", "Swaptions", "Streamcluster"), rotation=12.5)

#ax4.set_ylim(0.75, 2.5)

rects15 = ax2.bar([1, 7, 13, 19, 25, 31, 37, 43, 49, 55, 61], hermitux_means_b_norm, hatch="\\\\\\\\", color=["moccasin"], \
                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', \
                          'black'])
rects16 = ax2.bar([2, 8, 14, 20, 26, 32, 38, 44, 50, 56, 62], docker_means_b_norm, hatch="--", color=["lightgray"], \
                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', \
                          'black'])
rects17 = ax2.bar([3, 9, 15, 21, 27, 33, 39, 45, 51, 57, 63], osv_means_b_norm, color=["lightcoral"], \
                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', \
                          'black'])
rects18 = ax2.bar([4, 10, 16, 22, 28, 34, 40, 46, 52, 58, 64], rump_means_b_norm, hatch="////", color=["palegreen"], \
                edgecolor=['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', \
                          'black'])

#ax2.set_ylabel("Exec. time\nnormalized to Linux")    

l1 = mpatches.Patch(facecolor='skyblue', hatch="//", label='Linux', edgecolor='black')
l2 = mpatches.Patch(facecolor='moccasin', hatch="\\\\\\\\", label='HermiTux', edgecolor='black')
l3 = mpatches.Patch(facecolor='lightgray', hatch="---", label='Docker', edgecolor='black')
l4 = mpatches.Patch(facecolor='lightcoral', label='OSv', edgecolor='black')
l5 = mpatches.Patch(facecolor='palegreen', label='Rump', hatch="////", edgecolor='black')
ax1.legend(ncol=5, handles=[l2, l3, l4, l5], loc="upper left") #bbox_to_anchor=(1, .85))

ax2.legend(ncol=5, handles=[l2, l3, l4, l5], loc="upper left") #bbox_to_anchor=(1, .85))

#ax1.text(5, 45, "NPB class A and PARSEC Blackscholes SimLarge execution times comparison", fontsize=27, fontweight='bold')
#ax2.text(5, 1.17, "NPB class A and PARSEC Blackscholes SimLarge execution times normalized to Linux", fontsize=27, \
#        fontweight="bold")
#ax.text(6, 250, "NPB class B and PARSEC Blackscholes Native execution times comparison", fontsize=27, \
#        fontweight="bold")
#ax4.text(5, 2.1, "NPB class B and PARSEC Blackscholes Native execution times normalized to Linux", fontsize=27, \
#        fontweight="bold")

f.text(0.05, 0.5, 'Execution time normalized to Linux', ha='center', va='center', rotation='vertical')

ax1.text(55, 1.35, "Small datasets", fontweight='bold')
ax2.text(53.2, 2, "Medium datasets", fontweight='bold')

f.tight_layout(h_pad=0)
f.set_size_inches(11,4.5)
plt.savefig("NPB2.pdf")
