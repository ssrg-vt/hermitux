# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

matplotlib.rcParams.update({'font.size': 15})

# bandwidth in MB/s
linux_avg = 33.198
linux_std = 2.81444606746455
hermitux_avg = 9.4921
hermitux_std = 1.44837138039784
docker_avg = 13.501
docker_std = 2.25443488854007
osv_avg = 5.077
osv_std = 0.719645746183495
rump_avg = 4.223
rump_std = 0.636711167729223

means = [linux_avg, hermitux_avg, docker_avg, osv_avg, rump_avg]
stdevs = [linux_std, hermitux_std, docker_std, osv_std, rump_std]

fig, ax = plt.subplots()
ax.grid()
ax.set_axisbelow(True)

plt.xticks([0, 1, 2, 3, 4,], ["Linux", "HermiTux", "Docker", "OSv", "Rump"], rotation=15)
plt.ylabel("Measured bandwidth (MB/s)")

rects1 = ax.bar([0, 1, 2, 3, 4], means, yerr=stdevs, color=["skyblue", "moccasin", "lightgray", "lightcoral",\
            "palegreen"], edgecolor=['black', 'black', 'black', 'black', 'black'])

fig = matplotlib.pyplot.gcf()
#fig.subplots_adjust(left=0.2)
fig.subplots_adjust(bottom=0.2)
fig.set_size_inches(7,4)

plt.savefig("NetIO.pdf")
